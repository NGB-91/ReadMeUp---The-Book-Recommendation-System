# %%
import pandas as pd

# %%
# Load the dataset

df = pd.read_csv("../../data/final/books_translated.csv")
df = df.drop(columns=['Unnamed: 0'], errors='ignore')
df
# Out:
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice       Standalone Novel
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 57388    Beasts & Behemoths (Dungeons & Dragons)       Standalone Novel
# 57389                   Faculty of Dragon Riders       Standalone Novel
# 57390                      Midnight Delivery Sex       Standalone Novel
# 57391                            Monster Girl: 2       Standalone Novel
# 57392                        La saison du soleil       Standalone Novel
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary Grandpré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 57388  Jim Zub, Stacy King, Andrew Wheeler, Official ...    3.60
# 57389                                     Dmitry Nazarov    3.60
# 57390                                    Neneko Narazaki    4.00
# 57391                                     Kazuki Funatsu    3.50
# 57392                                  Shintaro Ishihara    4.04
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...       en
# 1      There is a door at the end of a silent corrido...       en
# 2      The unforgettable novel of a childhood in a sl...       en
# 3      Alternate cover edition of ISBN 9780679783268S...       en
# 4      About three things I was absolutely positive.\...       en
# ...                                                  ...      ...
# 57388  Study this guide and keep it close at hand--th...       en
# 57389  I tamed the Black Dragon!So I thought until I ...       en
# 57390  With SNS card for collecting in the first edit...       de
# 57391  Dopo il loro incontro, Yatsuki si ritrova ad a...       it
# 57392  Winner of the prestigious Akutagawa Prize in 1...       fr
#
#                                        genres bookFormat  pages  \
# 0        ['adventure', 'dystopia', 'fantasy']  Hardcover    374
# 1      ['adventure', 'childrens', 'classics']  Paperback    870
# 2       ['classics', 'fiction', 'historical']  Paperback    324
# 3       ['classics', 'fiction', 'historical']  Paperback    279
# 4        ['fantasy', 'fiction', 'paranormal']  Paperback    501
# ...                                       ...        ...    ...
# 57388                             ['fiction']  Paperback    114
# 57389                             ['fiction']  Paperback    401
# 57390                              ['comics']  Paperback     29
# 57391                    ['comics', 'isekai']  Paperback    216
# 57392                              ['isekai']  Paperback    131
#
#                               publisher          publishDate  \
# 0                      Scholastic Press  2008-09-14 00:00:00
# 1                       Scholastic Inc.  2004-09-28 00:00:00
# 2      Harper Perennial Modern Classics  2006-05-23 00:00:00
# 3                        Modern Library  2000-10-10 00:00:00
# 4             Little, Brown and Company  2006-09-06 00:00:00
# ...                                 ...                  ...
# 57388                   Ten Speed Press  2020-10-20 00:00:00
# 57389                            Litres  2022-08-24 00:00:00
# 57390                          Hayabusa  2021-05-04 00:00:00
# 57391                       Edizioni BD  2020-05-01 00:00:00
# 57392                           Belfond  2022-01-27 00:00:00
#
#        firstPublishDate  awards  \
# 0                 False    True
# 1                  True    True
# 2                  True    True
# 3                  True   False
# 4                  True    True
# ...                 ...     ...
# 57388              True   False
# 57389              True   False
# 57390              True   False
# 57391              True   False
# 57392              True   False
#
#                                                 coverImg  series_number  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...            1.0
# 1      https://i.gr-assets.com/images/S/compressed.ph...            5.0
# 2      https://i.gr-assets.com/images/S/compressed.ph...            NaN
# 3      https://i.gr-assets.com/images/S/compressed.ph...            NaN
# 4      https://i.gr-assets.com/images/S/compressed.ph...            1.0
# ...                                                  ...            ...
# 57388  http://books.google.com/books/content?id=1toui...            NaN
# 57389  http://books.google.com/books/content?id=QSGFE...            NaN
# 57390  http://books.google.com/books/content?id=s_8_E...            NaN
# 57391  http://books.google.com/books/content?id=_yjnE...            NaN
# 57392  http://books.google.com/books/content?id=bjZVE...            NaN
#
#        desc_length
# 0              147
# 1              136
# 2              137
# 3              100
# 4               55
# ...            ...
# 57388          170
# 57389           52
# 57390           78
# 57391           48
# 57392          138
#
# [57393 rows x 16 columns]

# %%
# Ensure the necessary columns are properly formatted

df['genres'] = df['genres'].apply(eval if isinstance(df['genres'].iloc[0], str) else lambda x: x)
df['author'] = df['author'].apply(lambda x: [a.strip() for a in x.split(',')])

# %%
# Model configuration

def multi_filter_recommendation(
    df,
    liked_genres=None,
    exclude_authors=None,
    selected_language=None,
    min_rating=0.0,
    top_n=10
):
    filtered_df = df.copy()

    # Filter by liked genres
    if liked_genres:
        filtered_df = filtered_df[
            filtered_df['genres'].apply(lambda genres: any(g in genres for g in liked_genres))
        ]

    # Filter by authors and exclude selected authors
    if exclude_authors:
        def no_excluded_authors(authors):
            return all(a.lower().strip() not in [e.lower().strip() for e in exclude_authors] for a in authors)

        filtered_df = filtered_df[
            filtered_df['author'].apply(no_excluded_authors)
        ]

    # Filter by language
    if selected_language:
        filtered_df = filtered_df[filtered_df['language'] == selected_language]

    # Filter by rating
    if min_rating > 0:
        filtered_df = filtered_df[filtered_df['rating'] >= min_rating]

    # Sort by rating and remove duplicates
    filtered_df = filtered_df.sort_values(by='rating', ascending=False)
    filtered_df = filtered_df.drop_duplicates(subset='title')

    # Selection of cleaned columns and limit to top_n results
    return filtered_df[['title', 'author', 'genres', 'rating', 'language']].head(top_n).reset_index(drop=True)

# %%
# Example usage of the recommendation function

liked_genres = ['fantasy', 'adventure']
exclude_authors = ['J.K. Rowling', 'Suzanne Collins']
language = 'en'
min_rating = 4.0

recommendations = multi_filter_recommendation(
    df,
    liked_genres=liked_genres,
    exclude_authors=exclude_authors,
    selected_language=language,
    min_rating=min_rating,
    top_n=10
)

pd.set_option('display.max_colwidth', None)  
print(recommendations.to_string(index=False))
# Out:
#                                                  title                                          author                          genres  rating language
#                                      Maze of Existence           [Tina M. Randolph (Goodreads Author)]                       [fantasy]    5.00       en
#                           Origins of The Wheel of Time                            [Michael Livingston]              [fantasy, fiction]    5.00       en
#                        Bertie's Book of Spooky Wonders                                [Ocelot Emerson]                       [fantasy]    5.00       en
#                               Orion: The Fight for Vox         [Ruth Watson-Morris (Goodreads Author)]                       [fantasy]    4.93       en
#           Elfquest: The Original Quest Gallery Edition      [Wendy Pini (Illustrations), Richard Pini]               [comics, fantasy]    4.90       en
#                                   Jellybean the Dragon               [Elias Zapple (Goodreads Author)] [adventure, childrens, fantasy]    4.89       en
#                   The Vampire King (The Horn King, #3)               [Brae Wyckoff (Goodreads Author)]                       [fantasy]    4.87       en
#           Elias Zapple's Rhymes from the Cabbage Patch               [Elias Zapple (Goodreads Author)]     [childrens, fantasy, humor]    4.87       en
# My First Fun Golf Steps (My First Travel Books Series) [Anna Othitis (Goodreads Author), John Othitis]          [adventure, childrens]    4.86       en
#          Keeper of the Lost Cities / Exile / Everblaze          [Shannon Messenger (Goodreads Author)]                       [fantasy]    4.86       en
